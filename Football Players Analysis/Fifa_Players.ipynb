# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
fifa = pd.read_csv('players_20.csv')

# %%
fifa.head()
# Out:
#    sofifa_id                                         player_url  \
# 0     158023  https://sofifa.com/player/158023/lionel-messi/...
# 1      20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 2     190871  https://sofifa.com/player/190871/neymar-da-sil...
# 3     200389  https://sofifa.com/player/200389/jan-oblak/20/...
# 4     183277  https://sofifa.com/player/183277/eden-hazard/2...
#
#           short_name                            long_name  age         dob  \
# 0           L. Messi       Lionel Andrés Messi Cuccittini   32  1987-06-24
# 1  Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   34  1985-02-05
# 2          Neymar Jr        Neymar da Silva Santos Junior   27  1992-02-05
# 3           J. Oblak                            Jan Oblak   26  1993-01-07
# 4          E. Hazard                          Eden Hazard   28  1991-01-07
#
#    height_cm  weight_kg nationality                 club  ...   lwb   ldm  \
# 0        170         72   Argentina         FC Barcelona  ...  68+2  66+2
# 1        187         83    Portugal             Juventus  ...  65+3  61+3
# 2        175         68      Brazil  Paris Saint-Germain  ...  66+3  61+3
# 3        188         87    Slovenia      Atlético Madrid  ...   NaN   NaN
# 4        175         74     Belgium          Real Madrid  ...  66+3  63+3
#
#     cdm   rdm   rwb    lb   lcb    cb   rcb    rb
# 0  66+2  66+2  68+2  63+2  52+2  52+2  52+2  63+2
# 1  61+3  61+3  65+3  61+3  53+3  53+3  53+3  61+3
# 2  61+3  61+3  66+3  61+3  46+3  46+3  46+3  61+3
# 3   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 4  63+3  63+3  66+3  61+3  49+3  49+3  49+3  61+3
#
# [5 rows x 104 columns]

# %%
fifa.tail()
# Out:
#        sofifa_id                                         player_url  \
# 18273     245006  https://sofifa.com/player/245006/shuai-shao/20...
# 18274     250995  https://sofifa.com/player/250995/mingjie-xiao/...
# 18275     252332  https://sofifa.com/player/252332/wei-zhang/20/...
# 18276     251110  https://sofifa.com/player/251110/haijian-wang/...
# 18277     233449  https://sofifa.com/player/233449/ximing-pan/20...
#
#          short_name     long_name  age         dob  height_cm  weight_kg  \
# 18273    Shao Shuai            邵帅   22  1997-03-10        186         79
# 18274  Xiao Mingjie  Mingjie Xiao   22  1997-01-01        177         66
# 18275     Zhang Wei            张威   19  2000-05-16        186         75
# 18276  Wang Haijian           汪海健   18  2000-08-02        185         74
# 18277    Pan Ximing           潘喜明   26  1993-01-11        182         78
#
#       nationality                           club  ...   lwb   ldm   cdm   rdm  \
# 18273    China PR               Beijing Renhe FC  ...  43+2  42+2  42+2  42+2
# 18274    China PR               Shanghai SIPG FC  ...  44+2  43+2  43+2  43+2
# 18275    China PR         Hebei China Fortune FC  ...  47+2  49+2  49+2  49+2
# 18276    China PR  Shanghai Greenland Shenhua FC  ...  48+2  48+2  48+2  48+2
# 18277    China PR         Hebei China Fortune FC  ...  48+2  49+2  49+2  49+2
#
#         rwb    lb   lcb    cb   rcb    rb
# 18273  43+2  45+2  46+2  46+2  46+2  45+2
# 18274  44+2  46+2  47+2  47+2  47+2  46+2
# 18275  47+2  47+2  49+2  49+2  49+2  47+2
# 18276  48+2  48+2  49+2  49+2  49+2  48+2
# 18277  48+2  48+2  50+2  50+2  50+2  48+2
#
# [5 rows x 104 columns]

# %%
fifa.columns
# Out:
# Index(['sofifa_id', 'player_url', 'short_name', 'long_name', 'age', 'dob',
#        'height_cm', 'weight_kg', 'nationality', 'club',
#        ...
#        'lwb', 'ldm', 'cdm', 'rdm', 'rwb', 'lb', 'lcb', 'cb', 'rcb', 'rb'],
#       dtype='object', length=104)

# %%
fifa.shape
# Out:
# (18278, 104)

# %%
fifa['nationality'].value_counts()
# Out:
# nationality
# England                1667
# Germany                1216
# Spain                  1035
# France                  984
# Argentina               886
#                        ...
# Liberia                   1
# São Tomé & Príncipe       1
# Puerto Rico               1
# Bahrain                   1
# Indonesia                 1
# Name: count, Length: 162, dtype: int64

# %%
fifa['nationality'].value_counts()[0:10]
# Out:
# nationality
# England        1667
# Germany        1216
# Spain          1035
# France          984
# Argentina       886
# Brazil          824
# Italy           732
# Colombia        591
# Japan           453
# Netherlands     416
# Name: count, dtype: int64

# %%
fifa['nationality'].value_counts()[0:5]
# Out:
# nationality
# England      1667
# Germany      1216
# Spain        1035
# France        984
# Argentina     886
# Name: count, dtype: int64

# %%
plt.figure(figsize=(8,5))
plt.bar(list(fifa['nationality'].value_counts()[0:5].keys()),list(fifa['nationality'].value_counts()[0:5]),color="green")
plt.show()

# %%
player_salary= fifa[['short_name','wage_eur']]

# %%
player_salary.head()
# Out:
#           short_name  wage_eur
# 0           L. Messi    565000
# 1  Cristiano Ronaldo    405000
# 2          Neymar Jr    290000
# 3           J. Oblak    125000
# 4          E. Hazard    470000

# %%
player_salary= player_salary.sort_values(by=['wage_eur'],ascending=False)

# %%
player_salary.head()
# Out:
#            short_name  wage_eur
# 0            L. Messi    565000
# 4           E. Hazard    470000
# 1   Cristiano Ronaldo    405000
# 5        K. De Bruyne    370000
# 22       A. Griezmann    370000

# %%
plt.figure(figsize=(8,5))
plt.bar(list(player_salary['short_name'])[0:5],list(player_salary['wage_eur'])[0:5],color="red")
plt.show()

# %%
fifa['nationality'] == 'Spain'
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 18273    False
# 18274    False
# 18275    False
# 18276    False
# 18277    False
# Name: nationality, Length: 18278, dtype: bool

# %%
#Spain
Spain = fifa[fifa['nationality']=='Spain']

# %%
Spain.head()
# Out:
#     sofifa_id                                         player_url  \
# 14     193080  https://sofifa.com/player/193080/david-de-gea-...
# 18     155862  https://sofifa.com/player/155862/sergio-ramos-...
# 21     189511  https://sofifa.com/player/189511/sergio-busque...
# 29     152729  https://sofifa.com/player/152729/gerard-pique-...
# 33     168542  https://sofifa.com/player/168542/david-josue-j...
#
#          short_name                  long_name  age         dob  height_cm  \
# 14           De Gea      David De Gea Quintana   28  1990-11-07        192
# 18     Sergio Ramos        Sergio Ramos García   33  1986-03-30        184
# 21  Sergio Busquets   Sergio Busquets i Burgos   30  1988-07-16        189
# 29            Piqué      Gerard Piqué Bernabéu   32  1987-02-02        194
# 33      David Silva  David Josué Jiménez Silva   33  1986-01-08        173
#
#     weight_kg nationality               club  ...   lwb   ldm   cdm   rdm  \
# 14         82       Spain  Manchester United  ...   NaN   NaN   NaN   NaN
# 18         82       Spain        Real Madrid  ...  80+3  84+3  84+3  84+3
# 21         76       Spain       FC Barcelona  ...  78+3  86+3  86+3  86+3
# 29         85       Spain       FC Barcelona  ...  77+3  83+3  83+3  83+3
# 33         67       Spain    Manchester City  ...  68+3  69+3  69+3  69+3
#
#      rwb    lb   lcb    cb   rcb    rb
# 14   NaN   NaN   NaN   NaN   NaN   NaN
# 18  80+3  82+3  87+3  87+3  87+3  82+3
# 21  78+3  78+3  82+3  82+3  82+3  78+3
# 29  77+3  78+3  85+3  85+3  85+3  78+3
# 33  68+3  63+3  56+3  56+3  56+3  63+3
#
# [5 rows x 104 columns]

# %%
Spain.sort_values(by=['height_cm'],ascending=False).head()
# Out:
#        sofifa_id                                         player_url  \
# 14235     231187  https://sofifa.com/player/231187/hodei-oleaga-...
# 14113     228789  https://sofifa.com/player/228789/robert-lynch-...
# 2486      189709  https://sofifa.com/player/189709/pedro-alcala-...
# 492       146748  https://sofifa.com/player/146748/diego-lopez-r...
# 842       195668  https://sofifa.com/player/195668/joel-robles-b...
#
#            short_name              long_name  age         dob  height_cm  \
# 14235          Oleaga   Hodei Oleaga Alarcia   22  1996-12-29        198
# 14113  Robert Sanchez   Robert Lynch Sanchez   21  1997-11-18        197
# 2486           Alcalá   Pedro Alcalá Guirado   30  1989-03-19        196
# 492       Diego López  Diego López Rodríguez   37  1981-11-03        196
# 842       Joel Robles   Joel Robles Blázquez   29  1990-06-17        195
#
#        weight_kg nationality                     club  ...   lwb   ldm   cdm  \
# 14235         87       Spain  Athletic Club de Bilbao  ...   NaN   NaN   NaN
# 14113         85       Spain                 Rochdale  ...   NaN   NaN   NaN
# 2486          93       Spain                Girona FC  ...  60+2  68+2  68+2
# 492           89       Spain             RCD Espanyol  ...   NaN   NaN   NaN
# 842           90       Spain               Real Betis  ...   NaN   NaN   NaN
#
#         rdm   rwb    lb   lcb    cb   rcb    rb
# 14235   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 14113   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2486   68+2  60+2  62+2  72+2  72+2  72+2  62+2
# 492     NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 842     NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
# [5 rows x 104 columns]

# %%
Spain.sort_values(by=['weight_kg'],ascending=False).head()
# Out:
#       sofifa_id                                         player_url  \
# 4556     191688  https://sofifa.com/player/191688/alberto-tomas...
# 1174     183666  https://sofifa.com/player/183666/roberto-jimen...
# 8121     211132  https://sofifa.com/player/211132/andres-tomas-...
# 2486     189709  https://sofifa.com/player/189709/pedro-alcala-...
# 286       24630  https://sofifa.com/player/24630/jose-manuel-re...
#
#          short_name                    long_name  age         dob  height_cm  \
# 4556          Botía  Alberto Tomás Botía Rabasco   30  1989-01-27        189
# 1174        Roberto         Roberto Jiménez Gago   33  1986-02-10        192
# 8121  Andrés Prieto   Andrés Tomás Prieto Albert   25  1993-10-17        194
# 2486         Alcalá         Pedro Alcalá Guirado   30  1989-03-19        196
# 286      Pepe Reina      José Manuel  Reina Páez   36  1982-08-31        188
#
#       weight_kg nationality             club  ...   lwb   ldm   cdm   rdm  \
# 4556         96       Spain         Al Hilal  ...  61+2  65+2  65+2  65+2
# 1174         94       Spain  West Ham United  ...   NaN   NaN   NaN   NaN
# 8121         93       Spain     RCD Espanyol  ...   NaN   NaN   NaN   NaN
# 2486         93       Spain        Girona FC  ...  60+2  68+2  68+2  68+2
# 286          92       Spain            Milan  ...   NaN   NaN   NaN   NaN
#
#        rwb    lb   lcb    cb   rcb    rb
# 4556  61+2  63+2  70+2  70+2  70+2  63+2
# 1174   NaN   NaN   NaN   NaN   NaN   NaN
# 8121   NaN   NaN   NaN   NaN   NaN   NaN
# 2486  60+2  62+2  72+2  72+2  72+2  62+2
# 286    NaN   NaN   NaN   NaN   NaN   NaN
#
# [5 rows x 104 columns]

# %%
Spain.sort_values(by=['wage_eur'],ascending=False).head()
# Out:
#     sofifa_id                                         player_url  \
# 18     155862  https://sofifa.com/player/155862/sergio-ramos-...
# 21     189511  https://sofifa.com/player/189511/sergio-busque...
# 29     152729  https://sofifa.com/player/152729/gerard-pique-...
# 33     168542  https://sofifa.com/player/168542/david-josue-j...
# 62     197781  https://sofifa.com/player/197781/francisco-rom...
#
#          short_name                       long_name  age         dob  \
# 18     Sergio Ramos             Sergio Ramos García   33  1986-03-30
# 21  Sergio Busquets        Sergio Busquets i Burgos   30  1988-07-16
# 29            Piqué           Gerard Piqué Bernabéu   32  1987-02-02
# 33      David Silva       David Josué Jiménez Silva   33  1986-01-08
# 62             Isco  Francisco Román Alarcón Suárez   27  1992-04-21
#
#     height_cm  weight_kg nationality             club  ...   lwb   ldm   cdm  \
# 18        184         82       Spain      Real Madrid  ...  80+3  84+3  84+3
# 21        189         76       Spain     FC Barcelona  ...  78+3  86+3  86+3
# 29        194         85       Spain     FC Barcelona  ...  77+3  83+3  83+3
# 33        173         67       Spain  Manchester City  ...  68+3  69+3  69+3
# 62        176         79       Spain      Real Madrid  ...  70+3  70+3  70+3
#
#      rdm   rwb    lb   lcb    cb   rcb    rb
# 18  84+3  80+3  82+3  87+3  87+3  87+3  82+3
# 21  86+3  78+3  78+3  82+3  82+3  82+3  78+3
# 29  83+3  77+3  78+3  85+3  85+3  85+3  78+3
# 33  69+3  68+3  63+3  56+3  56+3  56+3  63+3
# 62  70+3  70+3  67+3  62+3  62+3  62+3  67+3
#
# [5 rows x 104 columns]

# %%
#Brazil
Brazil = fifa[fifa['nationality']=='Brazil']

# %%
Brazil.head()
# Out:
#     sofifa_id                                         player_url   short_name  \
# 2      190871  https://sofifa.com/player/190871/neymar-da-sil...    Neymar Jr
# 13     212831  https://sofifa.com/player/212831/alisson-ramse...      Alisson
# 25     210257  https://sofifa.com/player/210257/ederson-santa...      Ederson
# 42     200145  https://sofifa.com/player/200145/carlos-henriq...     Casemiro
# 44     135507  https://sofifa.com/player/135507/fernando-luiz...  Fernandinho
#
#                             long_name  age         dob  height_cm  weight_kg  \
# 2       Neymar da Silva Santos Junior   27  1992-02-05        175         68
# 13              Alisson Ramses Becker   26  1992-10-02        191         91
# 25          Ederson Santana de Moraes   25  1993-08-17        188         86
# 42  Carlos Henrique Venancio Casimiro   27  1992-02-23        185         84
# 44                 Fernando Luiz Rosa   34  1985-05-04        179         67
#
#    nationality                 club  ...   lwb   ldm   cdm   rdm   rwb    lb  \
# 2       Brazil  Paris Saint-Germain  ...  66+3  61+3  61+3  61+3  66+3  61+3
# 13      Brazil            Liverpool  ...   NaN   NaN   NaN   NaN   NaN   NaN
# 25      Brazil      Manchester City  ...   NaN   NaN   NaN   NaN   NaN   NaN
# 42      Brazil          Real Madrid  ...  78+3  84+3  84+3  84+3  78+3  79+3
# 44      Brazil      Manchester City  ...  80+3  84+3  84+3  84+3  80+3  80+3
#
#      lcb    cb   rcb    rb
# 2   46+3  46+3  46+3  61+3
# 13   NaN   NaN   NaN   NaN
# 25   NaN   NaN   NaN   NaN
# 42  84+3  84+3  84+3  79+3
# 44  82+3  82+3  82+3  80+3
#
# [5 rows x 104 columns]

# %%
Brazil.sort_values(by=['wage_eur'],ascending=False).head()
# Out:
#      sofifa_id                                         player_url  \
# 2       190871  https://sofifa.com/player/190871/neymar-da-sil...
# 42      200145  https://sofifa.com/player/200145/carlos-henriq...
# 101     176676  https://sofifa.com/player/176676/marcelo-vieir...
# 44      135507  https://sofifa.com/player/135507/fernando-luiz...
# 25      210257  https://sofifa.com/player/210257/ederson-santa...
#
#       short_name                          long_name  age         dob  \
# 2      Neymar Jr      Neymar da Silva Santos Junior   27  1992-02-05
# 42      Casemiro  Carlos Henrique Venancio Casimiro   27  1992-02-23
# 101      Marcelo     Marcelo Vieira da Silva Júnior   31  1988-05-12
# 44   Fernandinho                 Fernando Luiz Rosa   34  1985-05-04
# 25       Ederson          Ederson Santana de Moraes   25  1993-08-17
#
#      height_cm  weight_kg nationality                 club  ...   lwb   ldm  \
# 2          175         68      Brazil  Paris Saint-Germain  ...  66+3  61+3
# 42         185         84      Brazil          Real Madrid  ...  78+3  84+3
# 101        174         75      Brazil          Real Madrid  ...  82+3  81+3
# 44         179         67      Brazil      Manchester City  ...  80+3  84+3
# 25         188         86      Brazil      Manchester City  ...   NaN   NaN
#
#       cdm   rdm   rwb    lb   lcb    cb   rcb    rb
# 2    61+3  61+3  66+3  61+3  46+3  46+3  46+3  61+3
# 42   84+3  84+3  78+3  79+3  84+3  84+3  84+3  79+3
# 101  81+3  81+3  82+3  81+3  79+3  79+3  79+3  81+3
# 44   84+3  84+3  80+3  80+3  82+3  82+3  82+3  80+3
# 25    NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
# [5 rows x 104 columns]

# %%
#Player Shooting
player_shooting = fifa[['short_name','shooting']]

# %%
player_shooting.sort_values(by=['shooting'],ascending=False).head()
# Out:
#             short_name  shooting
# 1    Cristiano Ronaldo      93.0
# 0             L. Messi      92.0
# 12             H. Kane      91.0
# 17           S. Agüero      90.0
# 205    F. Quagliarella      89.0

# %%
#Player Defending
player_defending = fifa[['short_name','defending','club']]

# %%
player_defending.sort_values(by=['defending'],ascending=False).head()
# Out:
#       short_name  defending               club
# 16  G. Chiellini       90.0           Juventus
# 7    V. van Dijk       90.0          Liverpool
# 11  K. Koulibaly       89.0             Napoli
# 35      D. Godín       89.0              Inter
# 49    M. Hummels       89.0  Borussia Dortmund

# %%
real_madrid = fifa[fifa['club'] == 'Real Madrid']

# %%
real_madrid.sort_values(by=['wage_eur'],ascending=False).head()
# Out:
#     sofifa_id                                         player_url  \
# 4      183277  https://sofifa.com/player/183277/eden-hazard/2...
# 8      177003  https://sofifa.com/player/177003/luka-modric/2...
# 36     182521  https://sofifa.com/player/182521/toni-kroos/20...
# 18     155862  https://sofifa.com/player/155862/sergio-ramos-...
# 46     165153  https://sofifa.com/player/165153/karim-benzema...
#
#       short_name            long_name  age         dob  height_cm  weight_kg  \
# 4      E. Hazard          Eden Hazard   28  1991-01-07        175         74
# 8      L. Modrić          Luka Modrić   33  1985-09-09        172         66
# 36      T. Kroos           Toni Kroos   29  1990-01-04        183         76
# 18  Sergio Ramos  Sergio Ramos García   33  1986-03-30        184         82
# 46    K. Benzema        Karim Benzema   31  1987-12-19        185         81
#
#    nationality         club  ...   lwb   ldm   cdm   rdm   rwb    lb   lcb  \
# 4      Belgium  Real Madrid  ...  66+3  63+3  63+3  63+3  66+3  61+3  49+3
# 8      Croatia  Real Madrid  ...  81+3  81+3  81+3  81+3  81+3  79+3  72+3
# 36     Germany  Real Madrid  ...  75+3  79+3  79+3  79+3  75+3  72+3  69+3
# 18       Spain  Real Madrid  ...  80+3  84+3  84+3  84+3  80+3  82+3  87+3
# 46      France  Real Madrid  ...  62+3  62+3  62+3  62+3  62+3  58+3  54+3
#
#       cb   rcb    rb
# 4   49+3  49+3  61+3
# 8   72+3  72+3  79+3
# 36  69+3  69+3  72+3
# 18  87+3  87+3  82+3
# 46  54+3  54+3  58+3
#
# [5 rows x 104 columns]

# %%
real_madrid.sort_values(by=['nationality'],ascending=False).head()
# Out:
#       sofifa_id                                         player_url  \
# 100      173731  https://sofifa.com/player/173731/gareth-bale/2...
# 1009     239053  https://sofifa.com/player/239053/federico-valv...
# 277      200724  https://sofifa.com/player/200724/jose-ignacio-...
# 9922     245290  https://sofifa.com/player/245290/adrian-de-la-...
# 8898     246608  https://sofifa.com/player/246608/alvaro-fidalg...
#
#            short_name                        long_name  age         dob  \
# 100           G. Bale                Gareth Frank Bale   29  1989-07-16
# 1009      F. Valverde                Federico Valverde   20  1998-07-22
# 277   Nacho Fernández  José Ignacio Fernández Iglesias   29  1990-01-18
# 9922     De la Fuente              Adrián de la Fuente   20  1999-02-22
# 8898          Fidalgo         Álvaro Fidalgo Fernández   22  1997-04-09
#
#       height_cm  weight_kg nationality         club  ...   lwb   ldm   cdm  \
# 100         185         82       Wales  Real Madrid  ...  72+3  69+3  69+3
# 1009        182         78     Uruguay  Real Madrid  ...  67+2  72+2  72+2
# 277         180         76       Spain  Real Madrid  ...  77+2  76+2  76+2
# 9922        179         78       Spain  Real Madrid  ...  58+2  60+2  60+2
# 8898        175         68       Spain  Real Madrid  ...  58+2  59+2  59+2
#
#        rdm   rwb    lb   lcb    cb   rcb    rb
# 100   69+3  72+3  70+3  66+3  66+3  66+3  70+3
# 1009  72+2  67+2  66+2  65+2  65+2  65+2  66+2
# 277   76+2  77+2  78+2  80+2  80+2  80+2  78+2
# 9922  60+2  58+2  59+2  63+2  63+2  63+2  59+2
# 8898  59+2  58+2  56+2  52+2  52+2  52+2  56+2
#
# [5 rows x 104 columns]

# %%
real_madrid.sort_values(by=['shooting'],ascending=False).head()
# Out:
#      sofifa_id                                         player_url  \
# 100     173731  https://sofifa.com/player/173731/gareth-bale/2...
# 106     198710  https://sofifa.com/player/198710/james-rodrigu...
# 4       183277  https://sofifa.com/player/183277/eden-hazard/2...
# 46      165153  https://sofifa.com/player/165153/karim-benzema...
# 161     232432  https://sofifa.com/player/232432/luka-jovic/20...
#
#        short_name                    long_name  age         dob  height_cm  \
# 100       G. Bale            Gareth Frank Bale   29  1989-07-16        185
# 106  J. Rodríguez  James David Rodríguez Rubio   27  1991-07-12        180
# 4       E. Hazard                  Eden Hazard   28  1991-01-07        175
# 46     K. Benzema                Karim Benzema   31  1987-12-19        185
# 161      L. Jović                   Luka Jović   21  1997-12-23        182
#
#      weight_kg nationality         club  ...   lwb   ldm   cdm   rdm   rwb  \
# 100         82       Wales  Real Madrid  ...  72+3  69+3  69+3  69+3  72+3
# 106         75    Colombia  Real Madrid  ...  67+3  67+3  67+3  67+3  67+3
# 4           74     Belgium  Real Madrid  ...  66+3  63+3  63+3  63+3  66+3
# 46          81      France  Real Madrid  ...  62+3  62+3  62+3  62+3  62+3
# 161         85      Serbia  Real Madrid  ...  55+2  53+2  53+2  53+2  55+2
#
#        lb   lcb    cb   rcb    rb
# 100  70+3  66+3  66+3  66+3  70+3
# 106  62+3  57+3  57+3  57+3  62+3
# 4    61+3  49+3  49+3  49+3  61+3
# 46   58+3  54+3  54+3  54+3  58+3
# 161  51+2  47+2  47+2  47+2  51+2
#
# [5 rows x 104 columns]

# %%
real_madrid.sort_values(by=['defending'],ascending=False).head()
# Out:
#      sofifa_id                                         player_url  \
# 18      155862  https://sofifa.com/player/155862/sergio-ramos-...
# 42      200145  https://sofifa.com/player/200145/carlos-henriq...
# 76      201535  https://sofifa.com/player/201535/raphael-varan...
# 94      204963  https://sofifa.com/player/204963/daniel-carvaj...
# 332     240130  https://sofifa.com/player/240130/eder-gabriel-...
#
#        short_name                          long_name  age         dob  \
# 18   Sergio Ramos                Sergio Ramos García   33  1986-03-30
# 42       Casemiro  Carlos Henrique Venancio Casimiro   27  1992-02-23
# 76      R. Varane                     Raphaël Varane   26  1993-04-25
# 94       Carvajal              Daniel Carvajal Ramos   27  1992-01-11
# 332  Éder Militão               Éder Gabriel Militão   21  1998-01-18
#
#      height_cm  weight_kg nationality         club  ...   lwb   ldm   cdm  \
# 18         184         82       Spain  Real Madrid  ...  80+3  84+3  84+3
# 42         185         84      Brazil  Real Madrid  ...  78+3  84+3  84+3
# 76         191         81      France  Real Madrid  ...  74+3  79+3  79+3
# 94         173         73       Spain  Real Madrid  ...  83+3  82+3  82+3
# 332        186         78      Brazil  Real Madrid  ...  78+2  76+2  76+2
#
#       rdm   rwb    lb   lcb    cb   rcb    rb
# 18   84+3  80+3  82+3  87+3  87+3  87+3  82+3
# 42   84+3  78+3  79+3  84+3  84+3  84+3  79+3
# 76   79+3  74+3  77+3  83+3  83+3  83+3  77+3
# 94   82+3  83+3  83+3  80+3  80+3  80+3  83+3
# 332  76+2  78+2  78+2  79+2  79+2  79+2  78+2
#
# [5 rows x 104 columns]

# %%
barcelona = fifa[fifa['club'] == 'FC Barcelona']

# %%
barcelona.sort_values(by=['nationality'],ascending=False).head()
# Out:
#       sofifa_id                                         player_url  \
# 19       176580  https://sofifa.com/player/176580/luis-suarez/2...
# 274      199564  https://sofifa.com/player/199564/sergio-robert...
# 602      241184  https://sofifa.com/player/241184/hector-junior...
# 9970     237522  https://sofifa.com/player/237522/jorge-cuenca-...
# 9938     242999  https://sofifa.com/player/242999/alex-collado-...
#
#          short_name                   long_name  age         dob  height_cm  \
# 19        L. Suárez    Luis Alberto Suárez Díaz   32  1987-01-24        182
# 274   Sergi Roberto     Sergio Roberto Carnicer   27  1992-02-07        178
# 602    Junior Firpo  Héctor Junior Firpo Adamés   22  1996-08-22        184
# 9970   Jorge Cuenca        Jorge Cuenca Barreno   19  1999-11-17        189
# 9938   Álex Collado      Álex Collado Gutiérrez   20  1999-04-22        177
#
#       weight_kg nationality          club  ...   lwb   ldm   cdm   rdm   rwb  \
# 19           86     Uruguay  FC Barcelona  ...  67+5  67+5  67+5  67+5  67+5
# 274          68       Spain  FC Barcelona  ...  80+3  79+3  79+3  79+3  80+3
# 602          78       Spain  FC Barcelona  ...  77+2  75+2  75+2  75+2  77+2
# 9970         76       Spain  FC Barcelona  ...  58+2  62+2  62+2  62+2  58+2
# 9938         66       Spain  FC Barcelona  ...  57+2  57+2  57+2  57+2  57+2
#
#         lb   lcb    cb   rcb    rb
# 19    64+5  63+5  63+5  63+5  64+5
# 274   79+3  75+3  75+3  75+3  79+3
# 602   77+2  75+2  75+2  75+2  77+2
# 9970  60+2  64+2  64+2  64+2  60+2
# 9938  56+2  52+2  52+2  52+2  56+2
#
# [5 rows x 104 columns]

# %%
barcelona.sort_values(by=['shooting'],ascending=False).head()
# Out:
#      sofifa_id                                         player_url  \
# 0       158023  https://sofifa.com/player/158023/lionel-messi/...
# 19      176580  https://sofifa.com/player/176580/luis-suarez/2...
# 22      194765  https://sofifa.com/player/194765/antoine-griez...
# 64      168651  https://sofifa.com/player/168651/ivan-rakitic/...
# 142     181872  https://sofifa.com/player/181872/arturo-vidal/...
#
#        short_name                       long_name  age         dob  height_cm  \
# 0        L. Messi  Lionel Andrés Messi Cuccittini   32  1987-06-24        170
# 19      L. Suárez        Luis Alberto Suárez Díaz   32  1987-01-24        182
# 22   A. Griezmann               Antoine Griezmann   28  1991-03-21        176
# 64     I. Rakitić                    Ivan Rakitić   31  1988-03-10        184
# 142      A. Vidal                    Arturo Vidal   32  1987-05-22        180
#
#      weight_kg nationality          club  ...   lwb   ldm   cdm   rdm   rwb  \
# 0           72   Argentina  FC Barcelona  ...  68+2  66+2  66+2  66+2  68+2
# 19          86     Uruguay  FC Barcelona  ...  67+5  67+5  67+5  67+5  67+5
# 22          73      France  FC Barcelona  ...  73+3  71+3  71+3  71+3  73+3
# 64          78     Croatia  FC Barcelona  ...  77+3  79+3  79+3  79+3  77+3
# 142         75       Chile  FC Barcelona  ...  81+3  84+3  84+3  84+3  81+3
#
#        lb   lcb    cb   rcb    rb
# 0    63+2  52+2  52+2  52+2  63+2
# 19   64+5  63+5  63+5  63+5  64+5
# 22   70+3  65+3  65+3  65+3  70+3
# 64   75+3  72+3  72+3  72+3  75+3
# 142  82+3  84+3  84+3  84+3  82+3
#
# [5 rows x 104 columns]

# %%
barcelona.sort_values(by=['defending'],ascending=False).head()
# Out:
#      sofifa_id                                         player_url  \
# 29      152729  https://sofifa.com/player/152729/gerard-pique-...
# 84      220440  https://sofifa.com/player/220440/clement-lengl...
# 59      205600  https://sofifa.com/player/205600/samuel-umtiti...
# 21      189511  https://sofifa.com/player/189511/sergio-busque...
# 142     181872  https://sofifa.com/player/181872/arturo-vidal/...
#
#           short_name                 long_name  age         dob  height_cm  \
# 29             Piqué     Gerard Piqué Bernabéu   32  1987-02-02        194
# 84        C. Lenglet           Clément Lenglet   24  1995-06-17        186
# 59         S. Umtiti             Samuel Umtiti   25  1993-11-14        182
# 21   Sergio Busquets  Sergio Busquets i Burgos   30  1988-07-16        189
# 142         A. Vidal              Arturo Vidal   32  1987-05-22        180
#
#      weight_kg nationality          club  ...   lwb   ldm   cdm   rdm   rwb  \
# 29          85       Spain  FC Barcelona  ...  77+3  83+3  83+3  83+3  77+3
# 84          81      France  FC Barcelona  ...  77+2  81+2  81+2  81+2  77+2
# 59          75      France  FC Barcelona  ...  77+3  80+3  80+3  80+3  77+3
# 21          76       Spain  FC Barcelona  ...  78+3  86+3  86+3  86+3  78+3
# 142         75       Chile  FC Barcelona  ...  81+3  84+3  84+3  84+3  81+3
#
#        lb   lcb    cb   rcb    rb
# 29   78+3  85+3  85+3  85+3  78+3
# 84   79+2  83+2  83+2  83+2  79+2
# 59   79+3  84+3  84+3  84+3  79+3
# 21   78+3  82+3  82+3  82+3  78+3
# 142  82+3  84+3  84+3  84+3  82+3
#
# [5 rows x 104 columns]
